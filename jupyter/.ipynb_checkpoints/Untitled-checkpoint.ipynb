# %%
import sys
sys.path.append("../")
import net_celebA
import chainer
import numpy as np
from glob import glob
import data
import chainer.serializers as S
import matplotlib.pyplot as plt
from PIL import Image
import os
import scipy.misc

# %%
e = net_celebA.Encoder()
d = net_celebA.Decoder()
m = "../results/model/epoch5_iter13000"
S.load_npz(m+ ".enc", e)
S.load_npz(m +".dec", d)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-a6a2dbdba52c> in <module>
#       2 d = net_celebA.Decoder()
#       3 m = "../results/model/epoch5_iter13000"
# ----> 4 S.load_npz(m+ ".enc", e)
#       5 S.load_npz(m +".dec", d)
#
# ~/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/chainer/serializers/npz.py in load_npz(file, obj, path, strict, ignore_names)
#     188         d = NpzDeserializer(
#     189             f, path=path, strict=strict, ignore_names=ignore_names)
# --> 190         d.load(obj)
#
# ~/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/chainer/serializer.py in load(self, obj)
#      81
#      82         """
# ---> 83         obj.serialize(self)
#
# ~/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/chainer/link.py in serialize(self, serializer)
#     995         d = self.__dict__
#     996         for name in self._children:
# --> 997             d[name].serialize(serializer[name])
#     998
#     999
#
# ~/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/chainer/link.py in serialize(self, serializer)
#     649         for name in self._params:
#     650             param = d[name]
# --> 651             data = serializer(name, param.data)
#     652             if param.data is None and data is not None:
#     653                 # Initialize the parameter here
#
# ~/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/chainer/serializers/npz.py in __call__(self, key, value)
#     141                     'list of them.')
#     142
# --> 143         dataset = self.npz[key]
#     144         if dataset[()] is None:
#     145             return None
#
# ~/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     253                 return self.zip.read(key)
#     254         else:
# --> 255             raise KeyError("%s is not a file in the archive" % key)
#     256
#     257
#
# KeyError: 'bn_mean/gamma is not a file in the archive'

# %%
files = np.array(glob("/home/oyamada/database/img_align_celeba/*.jpg"))

# %%
np.random.seed(100)
num_all = len(files)
num_train = int(num_all * 0.9)
num_test = num_all - num_train
id_all = np.random.choice(num_all, num_all, replace=False)
id_test = id_all[:num_test]
id_train = id_all[num_test:]
files_train, files_test = files[id_train], files[id_test]

# %%
# x = data.load(files_train[:10])
x = data.load(files_test[:10])

# %%
with chainer.using_config("train", False):
    q_z = e(x)
    z = q_z.sample(1)
    x_hat = d(z)

# %%
plt.imshow((x_hat.data[5].transpose([1, 2, 0]) + 1) / 2)

# %%
plt.imshow((x[5].transpose((1, 2, 0)) + 1)/2)

# %%
x = np.array(Image.open(files_train[50]))[(218-148)//2:(218-148)//2+148, (178-148)//2:(178-148)//2+148]

# %%
plt.imshow(scipy.misc.imresize(x, [128, 128]))
# Out:
# /home/oyamada/.pyenv/versions/3.6.5/envs/chainerV5/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.

# %%
h_min = 100000000
w_min = 100000000
for f in files:
    h, w, _ = np.array(Image.open(f)).shape
    if h < h_min:
        h_min = h
    if w < w_min:
        w_min = w

# %%
h_min
# Out:
# 218

# %%
w_min
# Out:
# 178
